# %% [markdown]
# # Data Preparation
#
# ## Deep Learning Final Project
#
# ### Jade Benson

# %% [markdown]
# In this project, we are interested in using multiple types of movie data from Wikipedia to describe this art form with deep learning methods. We aim to explore the different types of data individually and together to understand the landscape of movies. We will eventually use them to predict genre and whether movies pass the Bechdel test.

# %% [markdown]
# This notebook will combine three disparate data sources together.
#
# CMU Wikipedia plots, characters, genres, networks: http://www.cs.cmu.edu/~ark/personas/
#
# Movie poster links (Kaggle scraped from IMDB): https://www.kaggle.com/datasets/neha1703/movie-genre-from-its-poster
#
# Bechdel test: https://github.com/rfordatascience/tidytuesday/blob/master/data/2021/2021-03-09/readme.md

# %%
import pandas as pd 
import numpy as np 
import sklearn 
import matplotlib

# %%
## CMU Wikipedia movie dataset 

#first use "Movie meta data"
#Movie name, release data, genres, wikipedia movie ID 
#use wikipedia movie ID to link with the plot summaries in plot_summaries.txt

movie_info = pd.read_csv('MovieSummaries/movie.metadata.tsv', sep = '\t', header = None)

# %%
movie_info.head()
#final columns are dictionaries with freebase ID: value
# Out:
#           0           1                                                  2  \
# 0    975900   /m/03vyhn                                     Ghosts of Mars
# 1   3196793   /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
# 2  28463795  /m/0crgdbh                                        Brun bitter
# 3   9363483  /m/0285_cd                                   White Of The Eye
# 4    261236   /m/01mrr1                                  A Woman in Flames
#
#             3           4      5                                   6  \
# 0  2001-08-24  14010832.0   98.0  {"/m/02h40lc": "English Language"}
# 1  2000-02-16         NaN   95.0  {"/m/02h40lc": "English Language"}
# 2        1988         NaN   83.0  {"/m/05f_3": "Norwegian Language"}
# 3        1987         NaN  110.0  {"/m/02h40lc": "English Language"}
# 4        1983         NaN  106.0   {"/m/04306rv": "German Language"}
#
#                                            7  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                                    8
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}

# %%
movie_info.columns = ["wiki_ID", "freebase_ID", "title", "date", "revenue", "runtime", "language", "country", "genres"]

# %%
movie_info.head()
# Out:
#     wiki_ID freebase_ID                                              title  \
# 0    975900   /m/03vyhn                                     Ghosts of Mars
# 1   3196793   /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
# 2  28463795  /m/0crgdbh                                        Brun bitter
# 3   9363483  /m/0285_cd                                   White Of The Eye
# 4    261236   /m/01mrr1                                  A Woman in Flames
#
#          date     revenue  runtime                            language  \
# 0  2001-08-24  14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1  2000-02-16         NaN     95.0  {"/m/02h40lc": "English Language"}
# 2        1988         NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3        1987         NaN    110.0  {"/m/02h40lc": "English Language"}
# 4        1983         NaN    106.0   {"/m/04306rv": "German Language"}
#
#                                      country  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                               genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}

# %%
len(movie_info)
#81,741 movies
# Out:
# 81741

# %%
len(movie_info.drop_duplicates())
#no duplicates
# Out:
# 81741

# %%
#lowercase titles, no spaces or punctuation to hopefully make matching easier 
import re

clean_titles = lambda x: re.sub(r'[^a-z\d]', '', x.lower())
movie_info['match_title'] = movie_info["title"].apply(clean_titles)

# %%
movie_info.head()
# Out:
#     wiki_ID freebase_ID                                              title  \
# 0    975900   /m/03vyhn                                     Ghosts of Mars
# 1   3196793   /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
# 2  28463795  /m/0crgdbh                                        Brun bitter
# 3   9363483  /m/0285_cd                                   White Of The Eye
# 4    261236   /m/01mrr1                                  A Woman in Flames
#
#          date     revenue  runtime                            language  \
# 0  2001-08-24  14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1  2000-02-16         NaN     95.0  {"/m/02h40lc": "English Language"}
# 2        1988         NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3        1987         NaN    110.0  {"/m/02h40lc": "English Language"}
# 4        1983         NaN    106.0   {"/m/04306rv": "German Language"}
#
#                                      country  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                               genres  \
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}
#
#                                     match_title
# 0                                  ghostsofmars
# 1  gettingawaywithmurderthejonbentramseymystery
# 2                                    brunbitter
# 3                                 whiteoftheeye
# 4                                awomaninflames

# %%
#movie summaries also from CMU 

#code for how to merge with the summaries 

movie_lines = []

with open('MovieSummaries/plot_summaries.txt') as file:
    for line in file:
        line_clean = line.rstrip()
        line_clean = line_clean.split("\t")
        movie_lines.append(line_clean)

# %%
movie_lines[0:5]
# Out:
# [['23890098',
#   "Shlykov, a hard-working taxi driver and Lyosha, a saxophonist, develop a bizarre love-hate relationship, and despite their prejudices, realize they aren't so different after all."],
#  ['31186339',
#   'The nation of Panem consists of a wealthy Capitol and twelve poorer districts. As punishment for a past rebellion, each district must provide a boy and girl  between the ages of 12 and 18 selected by lottery  for the annual Hunger Games. The tributes must fight to the death in an arena; the sole survivor is rewarded with fame and wealth. In her first Reaping, 12-year-old Primrose Everdeen is chosen from District 12. Her older sister Katniss volunteers to take her place. Peeta Mellark, a baker\'s son who once gave Katniss bread when she was starving, is the other District 12 tribute. Katniss and Peeta are taken to the Capitol, accompanied by their frequently drunk mentor, past victor Haymitch Abernathy. He warns them about the "Career" tributes who train intensively at special academies and almost always win. During a TV interview with Caesar Flickerman, Peeta unexpectedly reveals his love for Katniss. She is outraged, believing it to be a ploy to gain audience support, as "sponsors" may provide in-Games gifts of food, medicine, and tools. However, she discovers Peeta meant what he said. The televised Games begin with half of the tributes killed in the first few minutes; Katniss barely survives ignoring Haymitch\'s advice to run away from the melee over the tempting supplies and weapons strewn in front of a structure called the Cornucopia. Peeta forms an uneasy alliance with the four Careers. They later find Katniss and corner her up a tree. Rue, hiding in a nearby tree, draws her attention to a poisonous tracker jacker nest hanging from a branch. Katniss drops it on her sleeping besiegers. They all scatter, except for Glimmer, who is killed by the insects. Hallucinating due to tracker jacker venom, Katniss is warned to run away by Peeta. Rue cares for Katniss for a couple of days until she recovers. Meanwhile, the alliance has gathered all the supplies into a pile. Katniss has Rue draw them off, then destroys the stockpile by setting off the mines planted around it. Furious, Cato kills the boy assigned to guard it. As Katniss runs from the scene, she hears Rue calling her name. She finds Rue trapped and releases her. Marvel, a tribute from District 1, throws a spear at Katniss, but she dodges the spear, causing it to stab Rue in the stomach instead. Katniss shoots him dead with an arrow. She then comforts the dying Rue with a song. Afterward, she gathers and arranges flowers around Rue\'s body. When this is televised, it sparks a riot in Rue\'s District 11. President Snow summons Seneca Crane, the Gamemaker, to express his displeasure at the way the Games are turning out. Since Katniss and Peeta have been presented to the public as "star-crossed lovers", Haymitch is able to convince Crane to make a rule change to avoid inciting further riots. It is announced that tributes from the same district can win as a pair. Upon hearing this, Katniss searches for Peeta and finds him with an infected sword wound in the leg. She portrays herself as deeply in love with him and gains a sponsor\'s gift of soup. An announcer proclaims a feast, where the thing each survivor needs most will be provided. Peeta begs her not to risk getting him medicine. Katniss promises not to go, but after he falls asleep, she heads to the feast. Clove ambushes her and pins her down. As Clove gloats, Thresh, the other District 11 tribute, kills Clove after overhearing her tormenting Katniss about killing Rue. He spares Katniss "just this time...for Rue". The medicine works, keeping Peeta mobile. Foxface, the girl from District 5, dies from eating nightlock berries she stole from Peeta; neither knew they are highly poisonous. Crane changes the time of day in the arena to late at night and unleashes a pack of hound-like creatures to speed things up. They kill Thresh and force Katniss and Peeta to flee to the roof of the Cornucopia, where they encounter Cato. After a battle, Katniss wounds Cato with an arrow and Peeta hurls him to the creatures below. Katniss sho ...
#  ['20663735',
#   "Poovalli Induchoodan  is sentenced for six years prison life for murdering his classmate. Induchoodan, the only son of Justice Maranchery Karunakara Menon  was framed in the case by Manapally Madhavan Nambiar  and his crony DYSP Sankaranarayanan  to take revenge on idealist judge Menon who had earlier given jail sentence to Manapally in a corruption case. Induchoodan, who had achieved top rank in Indian Civil Service loses the post and Manapally Sudheeran ([[Saikumar  enters the list of civil service trainees. We learn in flashback that it was Ramakrishnan  the son of Moopil Nair , who had actually killed his classmate. Six years passes by and Manapally Madhavan Nambiar, now a former state minister, is dead and Induchoodan, who is all rage at the gross injustice meted out to him - thus destroying his promising life, is released from prison. Induchoodan thwarts Manapally Pavithran  from performing the funeral rituals of Nambiar at Bharathapuzha. Many confrontations between Induchoodan and Manapally's henchmen follow. Induchoodan also falls in love with Anuradha ([[Aishwarya , the strong-willed and independent-minded daughter of Mooppil Nair. Justice Menon and his wife returns back to Kerala to stay with Induchoodan. There is an appearance of a girl named Indulekha ([[Kanaka , who claims to be the daughter of Justice Menon. Menon flatly refuses the claim and banishes her. Forced by circumstances and at the instigation and help of Manapally Pavithran, she reluctantly come out open with the claim. Induchoodan at first thrashes the protesters. But upon knowing the truth from Chandrabhanu his uncle, he accepts the task of her protection in the capacity as elder brother. Induchoodan decides to marry off Indulekha to his good friend Jayakrishnan . Induchoodan has a confrontation with his father and prods him to accept mistake and acknowledge the parentage of Indulekha. Menon ultimately regrets and goes on to confess to his daughter. The very next day, when Induchoodan returns to Poovally, Indulekha is found dead and Menon is accused of murdering her. The whole act was planned by Pavithran, who after killing Indulekha, forces Raman Nair  to testify against Menon in court. In court, Nandagopal Maarar , a close friend of Induchoodan and a famous supreme court lawyer, appears for Menon and manages to lay bare the murder plot and hidden intentions of other party . Menon is judged innocent of the crime by court. After confronting Pavithran and promising just retribution to the crime of killing Indulekha, Induchoodan returns to his father, who now shows remorse for all his actions including not believing in the innocence of his son. But while speaking to Induchoodan, Menon suffers a heart stroke and passes away. At Menon's funeral, Manapally Pavithran arrives to poke fun at Induchoodan and he also tries to carry out the postponed last rituals of his own father. Induchoodan interrupts the ritual and avenges for the death of his sister and father by severely injuring Pavithran. On his way back to peaceful life, Induchoodan accepts Anuradha as his life partner."],
#  ['2231378',
#   'The Lemon Drop Kid , a New York City swindler, is illegally touting horses at a Florida racetrack. After several successful hustles, the Kid comes across a beautiful, but gullible, woman intending to bet a lot of money. The Kid convinces her to switch her bet, employing a prefabricated con. Unfortunately for the Kid, the woman "belongs" to notorious gangster Moose Moran , as does the money. The Kid\'s choice finishes dead last and a furious Moran demands the Kid provide him with $10,000  by Christmas Eve, or the Kid "won\'t make it to New Year\'s." The Kid decides to return to New York to try to come up with the money. He first tries his on-again, off-again girlfriend Brainy Baxter . However, when talk of long-term commitment arises, the Kid quickly makes an escape. He next visits local crime boss "Oxford" Charley , with whom he has had past dealings. This falls through as Charley is in serious tax trouble and does not particularly care for the Kid anyway. As he leaves Charley\'s establishment and is about to give up hope, the Kid notices a cornerside Santa Claus and his kettle. Thinking quickly, the Kid fashions himself a Santa suit and begins collecting donations. This fails as he is recognized by a passing policeman, who remembers his previous underhanded activity well. The Kid lands in court, where he is convicted of collecting for a charity without a license and sentenced to ten days in jail . However, while in court, the Kid learns where his scheme went wrong. After a short stay, Brainy arrives to bail him out. He then sets about restarting his Santa operation, this time with legitimate backing. To this end, he needs a charity to represent and a city license. The kid receives key inspiration when he remembers that Nellie Thursday , a kindly neighborhood resident, has been denied entry to a retirement home because of her jailed husband\'s criminal past as a safecracker. Organizing other small-time New York swindlers and Brainy, who is both surprised and charmed at the Kid\'s apparent goodwill, the Kid converts an abandoned casino  into the "Nellie Thursday Home For Old Dolls". A small group of elderly women and makeshift amenities complete the project. The Kid is able to receive the all-important city license. Now free to collect, the Kid and his compatriots dress as Santa Claus and position themselves throughout Manhattan. The others are unaware that the Kid plans to keep the money for himself to pay off Moran. The scheme is a huge success, netting $2,000 in only a few days. An overjoyed Brainy decides to leave her job as a dancer and look after the "home" full-time until after Christmas. Coincidentally, her employer is none other than "Oxford" Charley, whom Brainy cheerfully informs of the effort. Seeing a potential gold mine, Charley decides to muscle in on the operation. Reasoning that the Nellie Thursday home is "wherever Nellie Thursday is", Charley and his crew kidnap the home\'s inhabitants  and move them to Charley\'s mansion in Nyack. The Kid learns of this when he returns to the home after a late night to find the home deserted and money  gone. Clued in by oversized Oxford footprints in the snow, the Kid and his friends pay Charley a visit. Here, Charley reveals the true nature of the Kid\'s scheme through a phone conversation with Moose Moran. The Kid\'s accomplices are angry and move to confront him, but the Kid manages to slip away. However, Brainy tracks him down outside and voices her disgust at his actions. After a few days of stewing in self-pity , the Kid is surprised to meet Nellie, who has escaped Charley\'s compound. He decides to recover the money, sneaking into Charley\'s home in the guise of an elderly woman. He finds that Charley and his crew are again moving the women, this time to a more secure location. Using the heightened activity to his advantage, the Kid enters Charley\'s office and confronts him. After a brief struggle, the Kid overpowers Charley and makes off with the money, narrowly  ...
#  ['595909',
#   'Seventh-day Adventist Church pastor Michael Chamberlain, his wife Lindy, their two sons, and their nine-week-old daughter Azaria are on a camping holiday in the Outback. With the baby sleeping in their tent, the family is enjoying a barbecue with their fellow campers when a cry is heard. Lindy returns to the tent to check on Azaria and is certain she sees a dingo with something in its mouth running off as she approaches. When she discovers the infant is missing, everyone joins forces to search for her, without success. It is assumed what Lindy saw was the animal carrying off the child, and a subsequent inquest rules her account of events is true. The tide of public opinion soon turns against the Chamberlains. For many, Lindy seems too stoic, too cold-hearted, and too accepting of the disaster that has befallen her. Gossip about her begins to swell and soon is accepted as statements of fact. The couple\'s beliefs are not widely practised in the country, and when the media report a rumour that the name Azaria means "sacrifice in the wilderness" , the public is quick to believe they decapitated their baby with a pair of scissors as part of a bizarre religious rite. Law-enforcement officials find new witnesses, forensics experts, and a lot of circumstantial evidence—including a small wooden coffin Michael uses as a receptacle for his parishioners\' packs of un-smoked cigarettes—and reopen the investigation, and eventually Lindy is charged with murder. Seven months pregnant, she ignores her attorneys\' advice to play on the jury\'s sympathy and appears emotionless on the stand, convincing onlookers she is guilty of the crime of which she is accused. As the trial progresses, Michael\'s faith in his religion and his belief in his wife disintegrate, and he stumbles through his testimony, suggesting he is concealing the truth. In October 1982, Lindy is found guilty and sentenced to life imprisonment with hard labour, while Michael is found guilty as an accessory and given an 18-month suspended sentence. More than three years later, while searching for the body of an English tourist who fell from Uluru, police discover a small item of clothing that is identified as the jacket Lindy had insisted Azaria was wearing over her jumpsuit, which had been recovered early in the investigation. She is immediately released from prison, the case reopened and all convictions against the Chamberlains overturned.']]

# %%
movie_plots = pd.DataFrame(movie_lines, columns = ['wiki_ID', 'plot'])
movie_plots.head()
#the plots should be cleaned before using!
# Out:
#     wiki_ID                                               plot
# 0  23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1  31186339  The nation of Panem consists of a wealthy Capi...
# 2  20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3   2231378  The Lemon Drop Kid , a New York City swindler,...
# 4    595909  Seventh-day Adventist Church pastor Michael Ch...

# %%
movie_plots.dtypes
# Out:
# wiki_ID    object
# plot       object
# dtype: object

# %%
movie_plots.wiki_ID = movie_plots.wiki_ID.astype(np.int64)

# %%
len(movie_plots)
# Out:
# 42306

# %%
len(movie_plots.drop_duplicates())
#no duplicates - good
# Out:
# 42306

# %%
#Merge with the CMU movie metadata 

movie_info_plots = movie_info.merge(movie_plots, how = 'inner', left_on = 'wiki_ID', right_on ='wiki_ID')

len(movie_info_plots)
#only dropped like 100 of the plots - much better
# Out:
# 42207

# %%
len(movie_info_plots.drop_duplicates())
#no duplicates
# Out:
# 42207

# %%
movie_info_plots.head(10)
# Out:
#     wiki_ID freebase_ID                      title        date      revenue  \
# 0    975900   /m/03vyhn             Ghosts of Mars  2001-08-24   14010832.0
# 1   9363483  /m/0285_cd           White Of The Eye        1987          NaN
# 2    261236   /m/01mrr1          A Woman in Flames        1983          NaN
# 3  18998739  /m/04jcqvw  The Sorcerer's Apprentice        2002          NaN
# 4   6631279   /m/0gffwj                Little city  1997-04-04          NaN
# 5    171005   /m/016ywb                    Henry V  1989-11-08   10161099.0
# 6  18296435  /m/04cqrs4               Aaah Belinda        1986          NaN
# 7  11250635  /m/02r52hc    The Mechanical Monsters         NaN          NaN
# 8     77856    /m/0kcn7               Mary Poppins  1964-08-27  102272727.0
# 9  32456683  /m/0gyryjt   Die Fahne von Kriwoj Rog        1967          NaN
#
#    runtime                            language  \
# 0     98.0  {"/m/02h40lc": "English Language"}
# 1    110.0  {"/m/02h40lc": "English Language"}
# 2    106.0   {"/m/04306rv": "German Language"}
# 3     86.0  {"/m/02h40lc": "English Language"}
# 4     93.0  {"/m/02h40lc": "English Language"}
# 5    137.0  {"/m/02h40lc": "English Language"}
# 6      NaN  {"/m/02hwyss": "Turkish Language"}
# 7      NaN  {"/m/02h40lc": "English Language"}
# 8    139.0  {"/m/02h40lc": "English Language"}
# 9    108.0   {"/m/04306rv": "German Language"}
#
#                                       country  \
# 0   {"/m/09c7w0": "United States of America"}
# 1              {"/m/07ssc": "United Kingdom"}
# 2                     {"/m/0345h": "Germany"}
# 3                {"/m/0hzlz": "South Africa"}
# 4   {"/m/09c7w0": "United States of America"}
# 5              {"/m/07ssc": "United Kingdom"}
# 6                     {"/m/01znc_": "Turkey"}
# 7   {"/m/09c7w0": "United States of America"}
# 8   {"/m/09c7w0": "United States of America"}
# 9  {"/m/03f2w": "German Democratic Republic"}
#
#                                               genres             match_title  \
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...            ghostsofmars
# 1  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...           whiteoftheeye
# 2                            {"/m/07s9rl0": "Drama"}          awomaninflames
# 3  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...  thesorcerersapprentice
# 4  {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...              littlecity
# 5  {"/m/04xvh5": "Costume drama", "/m/082gq": "Wa...                  henryv
# 6                             {"/m/01z4y": "Comedy"}             aaahbelinda
# 7  {"/m/06n90": "Science Fiction", "/m/03k9fj": "...   themechanicalmonsters
# 8  {"/m/0hj3myq": "Children's/Family", "/m/04t36"...             marypoppins
# 9                                                 {}    diefahnevonkriwojrog
#
#                                                 plot
# 0  Set in the second half of the 22nd century, th...
# 1  A series of murders of rich young women throug...
# 2  Eva, an upper class housewife, becomes frustra...
# 3  Every hundred years, the evil Morgana  returns...
# 4  Adam, a San Francisco-based artist who works a...
# 5  {{Plot|dateAct 1Act 2Act 3Act 4Act 5 Finally n...
# 6  Serap, a young actress with a strong, lively p...
# 7   The story starts as one of the robots flies i...
# 8  The film opens with Mary Poppins  perched in a...
# 9  Otto Brosowski, a communist miner, writes to t...

# %%
movie_info_plots.dtypes
# Out:
# wiki_ID          int64
# freebase_ID     object
# title           object
# date            object
# revenue        float64
# runtime        float64
# language        object
# country         object
# genres          object
# match_title     object
# plot            object
# dtype: object

# %%
#create simple year to help with merging 
import math
import datetime 

def clean_dates(date): 
    if isinstance(date, float) == True: 
        if np.isnan(date) == True: 
            return None
    
    elif isinstance(date, str) == True: 
        new_date = date.lstrip()
        
        #if date is more than 4 
        if len(new_date) > 4: 
            year = new_date[0:4]
            return year

        else: 
            return new_date

        
movie_info_plots['year'] = movie_info_plots.apply(lambda x: clean_dates(x.date), axis=1)

# %%
movie_info_plots.head(20)
# Out:
#      wiki_ID freebase_ID                                title        date  \
# 0     975900   /m/03vyhn                       Ghosts of Mars  2001-08-24
# 1    9363483  /m/0285_cd                     White Of The Eye        1987
# 2     261236   /m/01mrr1                    A Woman in Flames        1983
# 3   18998739  /m/04jcqvw            The Sorcerer's Apprentice        2002
# 4    6631279   /m/0gffwj                          Little city  1997-04-04
# 5     171005   /m/016ywb                              Henry V  1989-11-08
# 6   18296435  /m/04cqrs4                         Aaah Belinda        1986
# 7   11250635  /m/02r52hc              The Mechanical Monsters         NaN
# 8      77856    /m/0kcn7                         Mary Poppins  1964-08-27
# 9   32456683  /m/0gyryjt             Die Fahne von Kriwoj Rog        1967
# 10  21926710  /m/05p45cv                        White on Rice        2009
# 11  20604092  /m/0523t_1                          Anbu Thozhi  2007-08-17
# 12    156558   /m/014k4y                             Baby Boy  2001-06-27
# 13  11448183  /m/02rc_h4                     Bindiya Chamkegi  1984-01-20
# 14   9633533  /m/02pml15                             Vandanam        1989
# 15  29528534  /m/04j0lfk                        Anokha Rishta        1986
# 16  29772142  /m/0fq260_         Karayilekku Oru Kadal Dooram  2010-12-31
# 17  26067101  /m/0b6c_nw                          Siam Sunset        1999
# 18  26623942  /m/0bh9fbk                          Kausthubham  2010-03-19
# 19   9548445  /m/02pjlrp  Archie: To Riverdale and Back Again  1990-05-06
#
#         revenue  runtime                            language  \
# 0    14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1           NaN    110.0  {"/m/02h40lc": "English Language"}
# 2           NaN    106.0   {"/m/04306rv": "German Language"}
# 3           NaN     86.0  {"/m/02h40lc": "English Language"}
# 4           NaN     93.0  {"/m/02h40lc": "English Language"}
# 5    10161099.0    137.0  {"/m/02h40lc": "English Language"}
# 6           NaN      NaN  {"/m/02hwyss": "Turkish Language"}
# 7           NaN      NaN  {"/m/02h40lc": "English Language"}
# 8   102272727.0    139.0  {"/m/02h40lc": "English Language"}
# 9           NaN    108.0   {"/m/04306rv": "German Language"}
# 10          NaN     82.0                                  {}
# 11          NaN      NaN      {"/m/07c9s": "Tamil Language"}
# 12   29381649.0    123.0  {"/m/02h40lc": "English Language"}
# 13          NaN      NaN      {"/m/03k50": "Hindi Language"}
# 14          NaN    168.0  {"/m/0999q": "Malayalam Language"}
# 15          NaN    180.0      {"/m/03k50": "Hindi Language"}
# 16          NaN    110.0  {"/m/0999q": "Malayalam Language"}
# 17          NaN     91.0                                  {}
# 18          NaN      NaN  {"/m/0999q": "Malayalam Language"}
# 19          NaN    100.0  {"/m/02h40lc": "English Language"}
#
#                                               country  \
# 0           {"/m/09c7w0": "United States of America"}
# 1                      {"/m/07ssc": "United Kingdom"}
# 2                             {"/m/0345h": "Germany"}
# 3                        {"/m/0hzlz": "South Africa"}
# 4           {"/m/09c7w0": "United States of America"}
# 5                      {"/m/07ssc": "United Kingdom"}
# 6                             {"/m/01znc_": "Turkey"}
# 7           {"/m/09c7w0": "United States of America"}
# 8           {"/m/09c7w0": "United States of America"}
# 9          {"/m/03f2w": "German Democratic Republic"}
# 10          {"/m/09c7w0": "United States of America"}
# 11                              {"/m/03rk0": "India"}
# 12          {"/m/09c7w0": "United States of America"}
# 13                              {"/m/03rk0": "India"}
# 14                              {"/m/03rk0": "India"}
# 15                              {"/m/03rk0": "India"}
# 16                              {"/m/03rk0": "India"}
# 17  {"/m/0chghy": "Australia", "/m/0ctw_b": "New Z...
# 18                              {"/m/03rk0": "India"}
# 19          {"/m/09c7w0": "United States of America"}
#
#                                                genres  \
# 0   {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1   {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 2                             {"/m/07s9rl0": "Drama"}
# 3   {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...
# 4   {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...
# 5   {"/m/04xvh5": "Costume drama", "/m/082gq": "Wa...
# 6                              {"/m/01z4y": "Comedy"}
# 7   {"/m/06n90": "Science Fiction", "/m/03k9fj": "...
# 8   {"/m/0hj3myq": "Children's/Family", "/m/04t36"...
# 9                                                  {}
# 10  {"/m/06cvj": "Romantic comedy", "/m/02l7c8": "...
# 11                      {"/m/02l7c8": "Romance Film"}
# 12  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 13  {"/m/0hqxf": "Family Film", "/m/01z4y": "Comedy"}
# 14                           {"/m/02kdv5l": "Action"}
# 15  {"/m/03q4nz": "World cinema", "/m/04t36": "Mus...
# 16                            {"/m/07s9rl0": "Drama"}
# 17  {"/m/06cvj": "Romantic comedy", "/m/02l7c8": "...
# 18                            {"/m/07s9rl0": "Drama"}
# 19                             {"/m/01z4y": "Comedy"}
#
#                       match_title  \
# 0                    ghostsofmars
# 1                   whiteoftheeye
# 2                  awomaninflames
# 3          thesorcerersapprentice
# 4                      littlecity
# 5                          henryv
# 6                     aaahbelinda
# 7           themechanicalmonsters
# 8                     marypoppins
# 9            diefahnevonkriwojrog
# 10                    whiteonrice
# 11                     anbuthozhi
# 12                        babyboy
# 13                bindiyachamkegi
# 14                       vandanam
# 15                   anokharishta
# 16      karayilekkuorukadaldooram
# 17                     siamsunset
# 18                    kausthubham
# 19  archietoriverdaleandbackagain
#
#                                                  plot  year
# 0   Set in the second half of the 22nd century, th...  2001
# 1   A series of murders of rich young women throug...  1987
# 2   Eva, an upper class housewife, becomes frustra...  1983
# 3   Every hundred years, the evil Morgana  returns...  2002
# 4   Adam, a San Francisco-based artist who works a...  1997
# 5   {{Plot|dateAct 1Act 2Act 3Act 4Act 5 Finally n...  1989
# 6   Serap, a young actress with a strong, lively p...  1986
# 7    The story starts as one of the robots flies i...  None
# 8   The film opens with Mary Poppins  perched in a...  1964
# 9   Otto Brosowski, a communist miner, writes to t...  1967
# 10  Jimmy ([[Hiroshi Watanabe  loves dinosaurs and...  2009
# 11  The film opens with a simpleton from a small v...  2007
# 12  A young 20-year-old named Jody  lives with his...  2001
# 13  Shalini 'Shalu' lives a wealthy lifestyle with...  1984
# 14  Professor Kurian Fernandez , a convict escapes...  1989
# 15  Mary, an orphan lives in an orphanage run by n...  1986
# 16  Anoop Chandran , is a famous writer and award ...  2010
# 17  Perry is an English chemist working for a pain...  1999
# 18  The film is the story of Yamuna  whose life is...  2010
# 19  Archie Andrews, fifteen years after graduating...  1990

# %%
movie_info_plots.iloc[0,3]
# Out:
# '2001-08-24'

# %%
movie_info_plots.iloc[0,-1]
# Out:
# '2001'

# %% [markdown]
# ## Posters

# %%
# Poster dataset 
movie_posters = pd.read_csv('MoviePosters/MovieGenre.csv', encoding = "ISO-8859-1") #different encoding 
movie_posters.head()
# Out:
#    imdbId                           Imdb Link  \
# 0  114709  http://www.imdb.com/title/tt114709
# 1  113497  http://www.imdb.com/title/tt113497
# 2  113228  http://www.imdb.com/title/tt113228
# 3  114885  http://www.imdb.com/title/tt114885
# 4  113041  http://www.imdb.com/title/tt113041
#
#                                 Title  IMDB Score                       Genre  \
# 0                    Toy Story (1995)         8.3  Animation|Adventure|Comedy
# 1                      Jumanji (1995)         6.9     Action|Adventure|Family
# 2             Grumpier Old Men (1995)         6.6              Comedy|Romance
# 3            Waiting to Exhale (1995)         5.7        Comedy|Drama|Romance
# 4  Father of the Bride Part II (1995)         5.9       Comedy|Family|Romance
#
#                                               Poster
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
# 3  https://images-na.ssl-images-amazon.com/images...
# 4  https://images-na.ssl-images-amazon.com/images...

# %%
len(movie_posters)
# Out:
# 40108

# %%
#want to create new column with the years 
def extract_year(title): 
    split_title = re.split(' ', title)
    date = split_title[-1]
    year = re.sub(r'[()]', '', date)
    return year 

movie_posters['year'] = movie_posters.apply(lambda x: extract_year(x.Title), axis=1)

# %%
movie_posters.head(10)
# Out:
#    imdbId                           Imdb Link  \
# 0  114709  http://www.imdb.com/title/tt114709
# 1  113497  http://www.imdb.com/title/tt113497
# 2  113228  http://www.imdb.com/title/tt113228
# 3  114885  http://www.imdb.com/title/tt114885
# 4  113041  http://www.imdb.com/title/tt113041
# 5  113277  http://www.imdb.com/title/tt113277
# 6  114319  http://www.imdb.com/title/tt114319
# 7  112302  http://www.imdb.com/title/tt112302
# 8  114576  http://www.imdb.com/title/tt114576
# 9  113189  http://www.imdb.com/title/tt113189
#
#                                 Title  IMDB Score                       Genre  \
# 0                    Toy Story (1995)         8.3  Animation|Adventure|Comedy
# 1                      Jumanji (1995)         6.9     Action|Adventure|Family
# 2             Grumpier Old Men (1995)         6.6              Comedy|Romance
# 3            Waiting to Exhale (1995)         5.7        Comedy|Drama|Romance
# 4  Father of the Bride Part II (1995)         5.9       Comedy|Family|Romance
# 5                         Heat (1995)         8.2          Action|Crime|Drama
# 6                      Sabrina (1995)         6.3                Comedy|Drama
# 7                 Tom and Huck (1995)         5.6      Adventure|Comedy|Drama
# 8                 Sudden Death (1995)         5.7       Action|Crime|Thriller
# 9                    GoldenEye (1995)         7.2   Action|Adventure|Thriller
#
#                                               Poster             match_title  \
# 0  https://images-na.ssl-images-amazon.com/images...                toystory
# 1  https://images-na.ssl-images-amazon.com/images...                 jumanji
# 2  https://images-na.ssl-images-amazon.com/images...          grumpieroldmen
# 3  https://images-na.ssl-images-amazon.com/images...         waitingtoexhale
# 4  https://images-na.ssl-images-amazon.com/images...  fatherofthebridepartii
# 5  https://images-na.ssl-images-amazon.com/images...                    heat
# 6  https://images-na.ssl-images-amazon.com/images...                 sabrina
# 7  https://images-na.ssl-images-amazon.com/images...              tomandhuck
# 8  https://images-na.ssl-images-amazon.com/images...             suddendeath
# 9  https://images-na.ssl-images-amazon.com/images...               goldeneye
#
#    year
# 0  1995
# 1  1995
# 2  1995
# 3  1995
# 4  1995
# 5  1995
# 6  1995
# 7  1995
# 8  1995
# 9  1995

# %%
#now want to remove the dates 

#remove text from within parantheses 
remove_dates = lambda x: re.sub(r'\([^()]*\)', '', x)
movie_posters['match_title'] = movie_posters["Title"].apply(remove_dates)
movie_posters['match_title'] = movie_posters["match_title"].apply(clean_titles)

# %%
movie_posters.head(10)
#looks good
# Out:
#    imdbId                           Imdb Link  \
# 0  114709  http://www.imdb.com/title/tt114709
# 1  113497  http://www.imdb.com/title/tt113497
# 2  113228  http://www.imdb.com/title/tt113228
# 3  114885  http://www.imdb.com/title/tt114885
# 4  113041  http://www.imdb.com/title/tt113041
# 5  113277  http://www.imdb.com/title/tt113277
# 6  114319  http://www.imdb.com/title/tt114319
# 7  112302  http://www.imdb.com/title/tt112302
# 8  114576  http://www.imdb.com/title/tt114576
# 9  113189  http://www.imdb.com/title/tt113189
#
#                                 Title  IMDB Score                       Genre  \
# 0                    Toy Story (1995)         8.3  Animation|Adventure|Comedy
# 1                      Jumanji (1995)         6.9     Action|Adventure|Family
# 2             Grumpier Old Men (1995)         6.6              Comedy|Romance
# 3            Waiting to Exhale (1995)         5.7        Comedy|Drama|Romance
# 4  Father of the Bride Part II (1995)         5.9       Comedy|Family|Romance
# 5                         Heat (1995)         8.2          Action|Crime|Drama
# 6                      Sabrina (1995)         6.3                Comedy|Drama
# 7                 Tom and Huck (1995)         5.6      Adventure|Comedy|Drama
# 8                 Sudden Death (1995)         5.7       Action|Crime|Thriller
# 9                    GoldenEye (1995)         7.2   Action|Adventure|Thriller
#
#                                               Poster             match_title  \
# 0  https://images-na.ssl-images-amazon.com/images...                toystory
# 1  https://images-na.ssl-images-amazon.com/images...                 jumanji
# 2  https://images-na.ssl-images-amazon.com/images...          grumpieroldmen
# 3  https://images-na.ssl-images-amazon.com/images...         waitingtoexhale
# 4  https://images-na.ssl-images-amazon.com/images...  fatherofthebridepartii
# 5  https://images-na.ssl-images-amazon.com/images...                    heat
# 6  https://images-na.ssl-images-amazon.com/images...                 sabrina
# 7  https://images-na.ssl-images-amazon.com/images...              tomandhuck
# 8  https://images-na.ssl-images-amazon.com/images...             suddendeath
# 9  https://images-na.ssl-images-amazon.com/images...               goldeneye
#
#    year
# 0  1995
# 1  1995
# 2  1995
# 3  1995
# 4  1995
# 5  1995
# 6  1995
# 7  1995
# 8  1995
# 9  1995

# %%
movie_info_plots.head(10)
# Out:
#     wiki_ID freebase_ID                      title        date      revenue  \
# 0    975900   /m/03vyhn             Ghosts of Mars  2001-08-24   14010832.0
# 1   9363483  /m/0285_cd           White Of The Eye        1987          NaN
# 2    261236   /m/01mrr1          A Woman in Flames        1983          NaN
# 3  18998739  /m/04jcqvw  The Sorcerer's Apprentice        2002          NaN
# 4   6631279   /m/0gffwj                Little city  1997-04-04          NaN
# 5    171005   /m/016ywb                    Henry V  1989-11-08   10161099.0
# 6  18296435  /m/04cqrs4               Aaah Belinda        1986          NaN
# 7  11250635  /m/02r52hc    The Mechanical Monsters         NaN          NaN
# 8     77856    /m/0kcn7               Mary Poppins  1964-08-27  102272727.0
# 9  32456683  /m/0gyryjt   Die Fahne von Kriwoj Rog        1967          NaN
#
#    runtime                            language  \
# 0     98.0  {"/m/02h40lc": "English Language"}
# 1    110.0  {"/m/02h40lc": "English Language"}
# 2    106.0   {"/m/04306rv": "German Language"}
# 3     86.0  {"/m/02h40lc": "English Language"}
# 4     93.0  {"/m/02h40lc": "English Language"}
# 5    137.0  {"/m/02h40lc": "English Language"}
# 6      NaN  {"/m/02hwyss": "Turkish Language"}
# 7      NaN  {"/m/02h40lc": "English Language"}
# 8    139.0  {"/m/02h40lc": "English Language"}
# 9    108.0   {"/m/04306rv": "German Language"}
#
#                                       country  \
# 0   {"/m/09c7w0": "United States of America"}
# 1              {"/m/07ssc": "United Kingdom"}
# 2                     {"/m/0345h": "Germany"}
# 3                {"/m/0hzlz": "South Africa"}
# 4   {"/m/09c7w0": "United States of America"}
# 5              {"/m/07ssc": "United Kingdom"}
# 6                     {"/m/01znc_": "Turkey"}
# 7   {"/m/09c7w0": "United States of America"}
# 8   {"/m/09c7w0": "United States of America"}
# 9  {"/m/03f2w": "German Democratic Republic"}
#
#                                               genres             match_title  \
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...            ghostsofmars
# 1  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...           whiteoftheeye
# 2                            {"/m/07s9rl0": "Drama"}          awomaninflames
# 3  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...  thesorcerersapprentice
# 4  {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...              littlecity
# 5  {"/m/04xvh5": "Costume drama", "/m/082gq": "Wa...                  henryv
# 6                             {"/m/01z4y": "Comedy"}             aaahbelinda
# 7  {"/m/06n90": "Science Fiction", "/m/03k9fj": "...   themechanicalmonsters
# 8  {"/m/0hj3myq": "Children's/Family", "/m/04t36"...             marypoppins
# 9                                                 {}    diefahnevonkriwojrog
#
#                                                 plot  year
# 0  Set in the second half of the 22nd century, th...  2001
# 1  A series of murders of rich young women throug...  1987
# 2  Eva, an upper class housewife, becomes frustra...  1983
# 3  Every hundred years, the evil Morgana  returns...  2002
# 4  Adam, a San Francisco-based artist who works a...  1997
# 5  {{Plot|dateAct 1Act 2Act 3Act 4Act 5 Finally n...  1989
# 6  Serap, a young actress with a strong, lively p...  1986
# 7   The story starts as one of the robots flies i...  None
# 8  The film opens with Mary Poppins  perched in a...  1964
# 9  Otto Brosowski, a communist miner, writes to t...  1967

# %%
#inner merge between with the info/plots and the posters 
#use both the title and the year it was produced 
#this is smaller but more accurate 

movies_df = movie_info_plots.merge(movie_posters, how = 'inner', on = ['match_title', 'year'])

# %%
len(movies_df)
# Out:
# 15732

# %%
movies_df.head(10)
# Out:
#     wiki_ID freebase_ID                                title        date  \
# 0    975900   /m/03vyhn                       Ghosts of Mars  2001-08-24
# 1   9363483  /m/0285_cd                     White Of The Eye        1987
# 2   6631279   /m/0gffwj                          Little city  1997-04-04
# 3    171005   /m/016ywb                              Henry V  1989-11-08
# 4     77856    /m/0kcn7                         Mary Poppins  1964-08-27
# 5  21926710  /m/05p45cv                        White on Rice        2009
# 6    156558   /m/014k4y                             Baby Boy  2001-06-27
# 7  26067101  /m/0b6c_nw                          Siam Sunset        1999
# 8   9548445  /m/02pjlrp  Archie: To Riverdale and Back Again  1990-05-06
# 9  25960460  /m/0b6kc_5                       Daddy and Them        2001
#
#        revenue  runtime                            language  \
# 0   14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1          NaN    110.0  {"/m/02h40lc": "English Language"}
# 2          NaN     93.0  {"/m/02h40lc": "English Language"}
# 3   10161099.0    137.0  {"/m/02h40lc": "English Language"}
# 4  102272727.0    139.0  {"/m/02h40lc": "English Language"}
# 5          NaN     82.0                                  {}
# 6   29381649.0    123.0  {"/m/02h40lc": "English Language"}
# 7          NaN     91.0                                  {}
# 8          NaN    100.0  {"/m/02h40lc": "English Language"}
# 9          NaN    101.0  {"/m/02h40lc": "English Language"}
#
#                                              country  \
# 0          {"/m/09c7w0": "United States of America"}
# 1                     {"/m/07ssc": "United Kingdom"}
# 2          {"/m/09c7w0": "United States of America"}
# 3                     {"/m/07ssc": "United Kingdom"}
# 4          {"/m/09c7w0": "United States of America"}
# 5          {"/m/09c7w0": "United States of America"}
# 6          {"/m/09c7w0": "United States of America"}
# 7  {"/m/0chghy": "Australia", "/m/0ctw_b": "New Z...
# 8          {"/m/09c7w0": "United States of America"}
# 9  {"/m/09c7w0": "United States of America", "/m/...
#
#                                               genres  \
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 2  {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...
# 3  {"/m/04xvh5": "Costume drama", "/m/082gq": "Wa...
# 4  {"/m/0hj3myq": "Children's/Family", "/m/04t36"...
# 5  {"/m/06cvj": "Romantic comedy", "/m/02l7c8": "...
# 6  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 7  {"/m/06cvj": "Romantic comedy", "/m/02l7c8": "...
# 8                             {"/m/01z4y": "Comedy"}
# 9  {"/m/0vgkd": "Black comedy", "/m/01z4y": "Come...
#
#                      match_title  \
# 0                   ghostsofmars
# 1                  whiteoftheeye
# 2                     littlecity
# 3                         henryv
# 4                    marypoppins
# 5                    whiteonrice
# 6                        babyboy
# 7                     siamsunset
# 8  archietoriverdaleandbackagain
# 9                   daddyandthem
#
#                                                 plot  year  imdbId  \
# 0  Set in the second half of the 22nd century, th...  2001  228333
# 1  A series of murders of rich young women throug...  1987   94320
# 2  Adam, a San Francisco-based artist who works a...  1997  119548
# 3  {{Plot|dateAct 1Act 2Act 3Act 4Act 5 Finally n...  1989   97499
# 4  The film opens with Mary Poppins  perched in a...  1964   58331
# 5  Jimmy ([[Hiroshi Watanabe  loves dinosaurs and...  2009  892904
# 6  A young 20-year-old named Jody  lives with his...  2001  255819
# 7  Perry is an English chemist working for a pain...  1999  178022
# 8  Archie Andrews, fifteen years after graduating...  1990   99054
# 9  Ruby and Claude Montgomery are a very insecure...  2001  166158
#
#                             Imdb Link  \
# 0  http://www.imdb.com/title/tt228333
# 1   http://www.imdb.com/title/tt94320
# 2  http://www.imdb.com/title/tt119548
# 3   http://www.imdb.com/title/tt97499
# 4   http://www.imdb.com/title/tt58331
# 5  http://www.imdb.com/title/tt892904
# 6  http://www.imdb.com/title/tt255819
# 7  http://www.imdb.com/title/tt178022
# 8   http://www.imdb.com/title/tt99054
# 9  http://www.imdb.com/title/tt166158
#
#                                         Title  IMDB Score  \
# 0                       Ghosts of Mars (2001)         4.9
# 1                     White of the Eye (1987)         6.4
# 2                          Little City (1997)         6.1
# 3                              Henry V (1989)         7.7
# 4                         Mary Poppins (1964)         7.8
# 5                        White on Rice (2009)         6.2
# 6                             Baby Boy (2001)         6.4
# 7                          Siam Sunset (1999)         6.5
# 8  Archie: To Riverdale and Back Again (1990)         5.8
# 9                       Daddy and Them (2001)         5.7
#
#                       Genre                                             Poster
# 0      Action|Horror|Sci-Fi  https://images-na.ssl-images-amazon.com/images...
# 1           Horror|Thriller  https://images-na.ssl-images-amazon.com/images...
# 2            Comedy|Romance  https://images-na.ssl-images-amazon.com/images...
# 3    Action|Biography|Drama  https://images-na.ssl-images-amazon.com/images...
# 4     Comedy|Family|Fantasy  https://images-na.ssl-images-amazon.com/images...
# 5                    Comedy  https://images-na.ssl-images-amazon.com/images...
# 6       Crime|Drama|Romance  https://images-na.ssl-images-amazon.com/images...
# 7  Adventure|Comedy|Romance  https://images-na.ssl-images-amazon.com/images...
# 8             Comedy|Family  https://images-na.ssl-images-amazon.com/images...
# 9              Comedy|Drama  https://images-na.ssl-images-amazon.com/images...

# %%
print(len(movies_df.drop_duplicates()))
#there were duplicates (~400)

movies_df.drop_duplicates(inplace = True)
print(len(movies_df))
# Out:
# 15389
# 15389
# 15371

# %%
#any repeated wiki IDs? 
print(len(movies_df.drop_duplicates(subset = ['wiki_ID'])))
# Out:
# 15371

# %%
movies_df[movies_df.duplicated(subset = ['wiki_ID']) == True]
#these have different wiki IDs and plots but the same image and IMDB number, that's fine for our application.
# Out:
#         wiki_ID freebase_ID                            title        date  \
# 965      945305   /m/03s6l2  Confessions of a Dangerous Mind  2002-12-31
# 1290    1588930   /m/05drr_                   The Blue Angel  1930-04-01
# 1999   29475100  /m/03xzlz0                   Berlin Calling  2008-08-08
# 2672   34521846  /m/0j26mkz                         11/11/11  2011-11-01
# 2674   33388421  /m/0gy42wb                         11-11-11  2011-11-11
# 2712    2638362   /m/07tj4c                             Emma  1996-08-02
# 2876     535335   /m/02mmwk                War of the Worlds  2005-06-13
# 2998    4457586   /m/0c3hzc                          Soldier  1998-11-20
# 3000     730819   /m/036g88                          Soldier  1998-10-23
# 3493    2452691   /m/07f458                            Chaos  2005-08-10
# 3495    4198361   /m/0bphhp                            Chaos  2005-12-15
# 4413    1825914   /m/05zz4l                      The Warrior  2001-09-07
# 4601    3303352   /m/094fgb                        Crimewave        1985
# 5779    1395159   /m/04z5ml                    Clockstoppers  2002-03-29
# 7226      73170    /m/0jnwx                          Aladdin  1992-11-11
# 13046   8428660  /m/0273335                          Offside  2006-05-26
# 13623  12835554  /m/02x6xl_                          Darling  2007-09-07
# 14838   9105282  /m/027xt9k                    Men with Guns        1997
#
#            revenue  runtime  \
# 965     33013805.0    113.0
# 1290       77982.0    105.0
# 1999           NaN    100.0
# 2672     5739384.0     87.0
# 2674     5232771.0     90.0
# 2712    22231658.0    123.0
# 2876   591745550.0    112.0
# 2998           NaN      NaN
# 3000    14594226.0     99.0
# 3493       20166.0     74.0
# 3495     7000248.0    105.0
# 4413           NaN    158.0
# 4601           NaN     83.0
# 5779    38793283.0     93.0
# 7226   504050219.0     90.0
# 13046          NaN     88.0
# 13623          NaN    133.0
# 14838     910773.0    128.0
#
#                                                 language  \
# 965                   {"/m/02h40lc": "English Language"}
# 1290   {"/m/04306rv": "German Language", "/m/02h40lc"...
# 1999                   {"/m/04306rv": "German Language"}
# 2672                  {"/m/02h40lc": "English Language"}
# 2674                  {"/m/02h40lc": "English Language"}
# 2712                  {"/m/02h40lc": "English Language"}
# 2876                  {"/m/02h40lc": "English Language"}
# 2998                      {"/m/03k50": "Hindi Language"}
# 3000                  {"/m/02h40lc": "English Language"}
# 3493                  {"/m/02h40lc": "English Language"}
# 3495                  {"/m/02h40lc": "English Language"}
# 4413   {"/m/012w70": "Cantonese", "/m/0653m": "Standa...
# 4601                  {"/m/02h40lc": "English Language"}
# 5779                  {"/m/02h40lc": "English Language"}
# 7226                  {"/m/02h40lc": "English Language"}
# 13046                   {"/m/032f6": "Persian Language"}
# 13623                     {"/m/03k50": "Hindi Language"}
# 14838  {"/m/04h3_d": "Tzotzil language", "/m/03vsxc":...
#
#                                                  country  \
# 965    {"/m/09c7w0": "United States of America", "/m/...
# 1290   {"/m/084n_": "Weimar Republic", "/m/0345h": "G...
# 1999                             {"/m/0345h": "Germany"}
# 2672           {"/m/09c7w0": "United States of America"}
# 2674   {"/m/09c7w0": "United States of America", "/m/...
# 2712   {"/m/09c7w0": "United States of America", "/m/...
# 2876           {"/m/09c7w0": "United States of America"}
# 2998                               {"/m/03rk0": "India"}
# 3000   {"/m/09c7w0": "United States of America", "/m/...
# 3493           {"/m/09c7w0": "United States of America"}
# 3495   {"/m/09c7w0": "United States of America", "/m/...
# 4413   {"/m/06qd3": "South Korea", "/m/0d05w3": "China"}
# 4601           {"/m/09c7w0": "United States of America"}
# 5779           {"/m/09c7w0": "United States of America"}
# 7226           {"/m/09c7w0": "United States of America"}
# 13046                               {"/m/03shp": "Iran"}
# 13623  {"/m/03rk0": "India", "/m/07ssc": "United King...
# 14838          {"/m/09c7w0": "United States of America"}
#
#                                                   genres  \
# 965    {"/m/0lsxr": "Crime Fiction", "/m/01jfsb": "Th...
# 1290   {"/m/07s9rl0": "Drama", "/m/04t36": "Musical",...
# 1999   {"/m/07s9rl0": "Drama", "/m/01z4y": "Comedy", ...
# 2672     {"/m/01jfsb": "Thriller", "/m/03npn": "Horror"}
# 2674     {"/m/01jfsb": "Thriller", "/m/03npn": "Horror"}
# 2712   {"/m/06cvj": "Romantic comedy", "/m/04xvh5": "...
# 2876   {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 2998                           {"/m/01chg": "Bollywood"}
# 3000   {"/m/03btsm8": "Action/Adventure", "/m/06n90":...
# 3493   {"/m/0qdzd": "B-movie", "/m/03npn": "Horror", ...
# 3495   {"/m/01jfsb": "Thriller", "/m/0lsxr": "Crime F...
# 4413   {"/m/08322": "Wuxia", "/m/03q4nz": "World cine...
# 4601   {"/m/0lsxr": "Crime Fiction", "/m/0gf28": "Par...
# 5779   {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 7226   {"/m/03k9fj": "Adventure", "/m/04xvh5": "Costu...
# 13046  {"/m/02gk5": "Dogme 95", "/m/03q4nz": "World c...
# 13623  {"/m/07s9rl0": "Drama", "/m/04t36": "Musical",...
# 14838  {"/m/03btsm8": "Action/Adventure", "/m/07s9rl0...
#
#                        match_title  \
# 965    confessionsofadangerousmind
# 1290                  theblueangel
# 1999                 berlincalling
# 2672                        111111
# 2674                        111111
# 2712                          emma
# 2876                waroftheworlds
# 2998                       soldier
# 3000                       soldier
# 3493                         chaos
# 3495                         chaos
# 4413                    thewarrior
# 4601                     crimewave
# 5779                 clockstoppers
# 7226                       aladdin
# 13046                      offside
# 13623                      darling
# 14838                  menwithguns
#
#                                                     plot  year   imdbId  \
# 965    Tired of being rejected by the beautiful women...  2002   270288
# 1290   Immanuel Rath  is an esteemed educator at the ...  1930   818931
# 1999   Berlin techno DJ and producer Martin Karow  is...  2008   211946
# 2672   Jack and Melissa Vales become increasingly fri...  2011  2015261
# 2674   The film starts with a dream sequence depictin...  2011  2015261
# 2712   The film describes a year in the life of Emma ...  1996   118308
# 2876   Ray Ferrier  is a container crane operator at ...  2005   449040
# 2998   Captain Vijay Malhotra  attempts to defend him...  1998   211634
# 3000   In the near future, as part of a new military ...  1998   211634
# 3493   While living at her parents' mountain home, Em...  2005   405977
# 3495   During a hostage incident on a bridge, Detecti...  2005   405977
# 4413   In 1375, a small political envoy travels to Mi...  2001   295682
# 4601   The film's story concerns Victor Ajax , a youn...  1985    88963
# 5779   The NSA-funded QT  Corporation has slated a pr...  2002   157472
# 7226   Jafar, Grand Vizier to the Sultan of Agrabah, ...  1992   827990
# 13046  Most of the characters in the film are not nam...  2006   774755
# 13623  Aditya is seemingly living every Indian man's ...  2007   881233
# 14838   Dr. Fuentes  is a medical professor/doctor ne...  1997   119657
#
#                                  Imdb Link  \
# 965     http://www.imdb.com/title/tt270288
# 1290    http://www.imdb.com/title/tt818931
# 1999    http://www.imdb.com/title/tt211946
# 2672   http://www.imdb.com/title/tt2015261
# 2674   http://www.imdb.com/title/tt2015261
# 2712    http://www.imdb.com/title/tt118308
# 2876    http://www.imdb.com/title/tt449040
# 2998    http://www.imdb.com/title/tt211634
# 3000    http://www.imdb.com/title/tt211634
# 3493    http://www.imdb.com/title/tt405977
# 3495    http://www.imdb.com/title/tt405977
# 4413    http://www.imdb.com/title/tt295682
# 4601     http://www.imdb.com/title/tt88963
# 5779    http://www.imdb.com/title/tt157472
# 7226    http://www.imdb.com/title/tt827990
# 13046   http://www.imdb.com/title/tt774755
# 13623   http://www.imdb.com/title/tt881233
# 14838   http://www.imdb.com/title/tt119657
#
#                                         Title  IMDB Score  \
# 965    Confessions of a Dangerous Mind (2002)         7.1
# 1290                    The Blue Angel (1930)         7.8
# 1999                    Berlin Calling (2008)         7.3
# 2672                          11/11/11 (2011)         2.6
# 2674                          11/11/11 (2011)         2.6
# 2712                              Emma (1996)         7.1
# 2876                 War of the Worlds (2005)         3.3
# 2998                           Soldier (1998)         6.1
# 3000                           Soldier (1998)         6.1
# 3493                             Chaos (2005)         3.2
# 3495                             Chaos (2005)         3.2
# 4413                       The Warrior (2001)         6.8
# 4601                        Crime Wave (1985)         7.2
# 5779                     Clockstoppers (2002)         5.2
# 7226                           Aladdin (1992)         6.4
# 13046                          Offside (2006)         5.8
# 13623                          Darling (2007)         6.7
# 14838                    Men with Guns (1997)         7.6
#
#                             Genre  \
# 965        Biography|Comedy|Crime
# 1290                  Drama|Music
# 1999           Comedy|Drama|Music
# 2672              Horror|Thriller
# 2674              Horror|Thriller
# 2712         Comedy|Drama|Romance
# 2876                       Sci-Fi
# 2998         Action|Drama|Musical
# 3000         Action|Drama|Musical
# 3493        Crime|Horror|Thriller
# 3495        Crime|Horror|Thriller
# 4413              Adventure|Drama
# 4601             Adventure|Comedy
# 5779      Action|Adventure|Comedy
# 7226   Animation|Adventure|Comedy
# 13046          Comedy|Drama|Sport
# 13623             Biography|Drama
# 14838             Adventure|Drama
#
#                                                   Poster
# 965    https://images-na.ssl-images-amazon.com/images...
# 1290   https://images-na.ssl-images-amazon.com/images...
# 1999   https://images-na.ssl-images-amazon.com/images...
# 2672   https://images-na.ssl-images-amazon.com/images...
# 2674   https://images-na.ssl-images-amazon.com/images...
# 2712   https://images-na.ssl-images-amazon.com/images...
# 2876   https://images-na.ssl-images-amazon.com/images...
# 2998   https://images-na.ssl-images-amazon.com/images...
# 3000   https://images-na.ssl-images-amazon.com/images...
# 3493   https://images-na.ssl-images-amazon.com/images...
# 3495   https://images-na.ssl-images-amazon.com/images...
# 4413   https://images-na.ssl-images-amazon.com/images...
# 4601   https://images-na.ssl-images-amazon.com/images...
# 5779   https://images-na.ssl-images-amazon.com/images...
# 7226   https://images-na.ssl-images-amazon.com/images...
# 13046  https://images-na.ssl-images-amazon.com/images...
# 13623  https://images-na.ssl-images-amazon.com/images...
# 14838  https://images-na.ssl-images-amazon.com/images...

# %%
movies_df.head(10)
# Out:
#     wiki_ID freebase_ID                                title        date  \
# 0    975900   /m/03vyhn                       Ghosts of Mars  2001-08-24
# 1   9363483  /m/0285_cd                     White Of The Eye        1987
# 2   6631279   /m/0gffwj                          Little city  1997-04-04
# 3    171005   /m/016ywb                              Henry V  1989-11-08
# 4     77856    /m/0kcn7                         Mary Poppins  1964-08-27
# 5  21926710  /m/05p45cv                        White on Rice        2009
# 6    156558   /m/014k4y                             Baby Boy  2001-06-27
# 7  26067101  /m/0b6c_nw                          Siam Sunset        1999
# 8   9548445  /m/02pjlrp  Archie: To Riverdale and Back Again  1990-05-06
# 9  25960460  /m/0b6kc_5                       Daddy and Them        2001
#
#        revenue  runtime                            language  \
# 0   14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1          NaN    110.0  {"/m/02h40lc": "English Language"}
# 2          NaN     93.0  {"/m/02h40lc": "English Language"}
# 3   10161099.0    137.0  {"/m/02h40lc": "English Language"}
# 4  102272727.0    139.0  {"/m/02h40lc": "English Language"}
# 5          NaN     82.0                                  {}
# 6   29381649.0    123.0  {"/m/02h40lc": "English Language"}
# 7          NaN     91.0                                  {}
# 8          NaN    100.0  {"/m/02h40lc": "English Language"}
# 9          NaN    101.0  {"/m/02h40lc": "English Language"}
#
#                                              country  \
# 0          {"/m/09c7w0": "United States of America"}
# 1                     {"/m/07ssc": "United Kingdom"}
# 2          {"/m/09c7w0": "United States of America"}
# 3                     {"/m/07ssc": "United Kingdom"}
# 4          {"/m/09c7w0": "United States of America"}
# 5          {"/m/09c7w0": "United States of America"}
# 6          {"/m/09c7w0": "United States of America"}
# 7  {"/m/0chghy": "Australia", "/m/0ctw_b": "New Z...
# 8          {"/m/09c7w0": "United States of America"}
# 9  {"/m/09c7w0": "United States of America", "/m/...
#
#                                               genres  \
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 2  {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...
# 3  {"/m/04xvh5": "Costume drama", "/m/082gq": "Wa...
# 4  {"/m/0hj3myq": "Children's/Family", "/m/04t36"...
# 5  {"/m/06cvj": "Romantic comedy", "/m/02l7c8": "...
# 6  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 7  {"/m/06cvj": "Romantic comedy", "/m/02l7c8": "...
# 8                             {"/m/01z4y": "Comedy"}
# 9  {"/m/0vgkd": "Black comedy", "/m/01z4y": "Come...
#
#                      match_title  \
# 0                   ghostsofmars
# 1                  whiteoftheeye
# 2                     littlecity
# 3                         henryv
# 4                    marypoppins
# 5                    whiteonrice
# 6                        babyboy
# 7                     siamsunset
# 8  archietoriverdaleandbackagain
# 9                   daddyandthem
#
#                                                 plot  year  imdbId  \
# 0  Set in the second half of the 22nd century, th...  2001  228333
# 1  A series of murders of rich young women throug...  1987   94320
# 2  Adam, a San Francisco-based artist who works a...  1997  119548
# 3  {{Plot|dateAct 1Act 2Act 3Act 4Act 5 Finally n...  1989   97499
# 4  The film opens with Mary Poppins  perched in a...  1964   58331
# 5  Jimmy ([[Hiroshi Watanabe  loves dinosaurs and...  2009  892904
# 6  A young 20-year-old named Jody  lives with his...  2001  255819
# 7  Perry is an English chemist working for a pain...  1999  178022
# 8  Archie Andrews, fifteen years after graduating...  1990   99054
# 9  Ruby and Claude Montgomery are a very insecure...  2001  166158
#
#                             Imdb Link  \
# 0  http://www.imdb.com/title/tt228333
# 1   http://www.imdb.com/title/tt94320
# 2  http://www.imdb.com/title/tt119548
# 3   http://www.imdb.com/title/tt97499
# 4   http://www.imdb.com/title/tt58331
# 5  http://www.imdb.com/title/tt892904
# 6  http://www.imdb.com/title/tt255819
# 7  http://www.imdb.com/title/tt178022
# 8   http://www.imdb.com/title/tt99054
# 9  http://www.imdb.com/title/tt166158
#
#                                         Title  IMDB Score  \
# 0                       Ghosts of Mars (2001)         4.9
# 1                     White of the Eye (1987)         6.4
# 2                          Little City (1997)         6.1
# 3                              Henry V (1989)         7.7
# 4                         Mary Poppins (1964)         7.8
# 5                        White on Rice (2009)         6.2
# 6                             Baby Boy (2001)         6.4
# 7                          Siam Sunset (1999)         6.5
# 8  Archie: To Riverdale and Back Again (1990)         5.8
# 9                       Daddy and Them (2001)         5.7
#
#                       Genre                                             Poster
# 0      Action|Horror|Sci-Fi  https://images-na.ssl-images-amazon.com/images...
# 1           Horror|Thriller  https://images-na.ssl-images-amazon.com/images...
# 2            Comedy|Romance  https://images-na.ssl-images-amazon.com/images...
# 3    Action|Biography|Drama  https://images-na.ssl-images-amazon.com/images...
# 4     Comedy|Family|Fantasy  https://images-na.ssl-images-amazon.com/images...
# 5                    Comedy  https://images-na.ssl-images-amazon.com/images...
# 6       Crime|Drama|Romance  https://images-na.ssl-images-amazon.com/images...
# 7  Adventure|Comedy|Romance  https://images-na.ssl-images-amazon.com/images...
# 8             Comedy|Family  https://images-na.ssl-images-amazon.com/images...
# 9              Comedy|Drama  https://images-na.ssl-images-amazon.com/images...

# %%
#save this 

movies_df.to_csv('movies.csv')

# %%
# Missingness exploration

#what posters are being dropped? 

final_ids = movies_df['imdbId']

# %%
missing_posters = movie_posters[~movie_posters['imdbId'].isin(final_ids)]
len(missing_posters)
# Out:
# 21241

# %%
missing_posters.head(50)
#these look like foreign movies or very small movies?
#might not have wikipedia pages
# Out:
#      imdbId                           Imdb Link  \
# 29   115012  http://www.imdb.com/title/tt115012
# 32   114952  http://www.imdb.com/title/tt114952
# 36   112286  http://www.imdb.com/title/tt112286
# 39   112749  http://www.imdb.com/title/tt112749
# 45   113347  http://www.imdb.com/title/tt113347
# 46   114369  http://www.imdb.com/title/tt114369
# 50   109950  http://www.imdb.com/title/tt109950
# 54   113158  http://www.imdb.com/title/tt113158
# 55   113541  http://www.imdb.com/title/tt113541
# 57   110877  http://www.imdb.com/title/tt110877
# 58   112714  http://www.imdb.com/title/tt112714
# 71   113537  http://www.imdb.com/title/tt113537
# 76   113973  http://www.imdb.com/title/tt113973
# 81   112379  http://www.imdb.com/title/tt112379
# 82   114039  http://www.imdb.com/title/tt114039
# 83   113612  http://www.imdb.com/title/tt113612
# 84   112365  http://www.imdb.com/title/tt112365
# 89   113490  http://www.imdb.com/title/tt113490
# 96   111173  http://www.imdb.com/title/tt111173
# 97   113283  http://www.imdb.com/title/tt113283
# 104  110251  http://www.imdb.com/title/tt110251
# 106  112646  http://www.imdb.com/title/tt112646
# 107  113276  http://www.imdb.com/title/tt113276
# 114  112373  http://www.imdb.com/title/tt112373
# 119  106473  http://www.imdb.com/title/tt106473
# 125  111055  http://www.imdb.com/title/tt111055
# 126  110217  http://www.imdb.com/title/tt110217
# 127  114131  http://www.imdb.com/title/tt114131
# 129  113107  http://www.imdb.com/title/tt113107
# 131  114015  http://www.imdb.com/title/tt114015
# 132  114500  http://www.imdb.com/title/tt114500
# 134  113125  http://www.imdb.com/title/tt113125
# 136  113952  http://www.imdb.com/title/tt113952
# 140   94878   http://www.imdb.com/title/tt94878
# 141  113200  http://www.imdb.com/title/tt113200
# 152   61395   http://www.imdb.com/title/tt61395
# 154  112541  http://www.imdb.com/title/tt112541
# 155  109370  http://www.imdb.com/title/tt109370
# 160  109508  http://www.imdb.com/title/tt109508
# 176  107447  http://www.imdb.com/title/tt107447
# 182  110620  http://www.imdb.com/title/tt110620
# 203  114798  http://www.imdb.com/title/tt114798
# 204  114805  http://www.imdb.com/title/tt114805
# 223  112899  http://www.imdb.com/title/tt112899
# 239  109771  http://www.imdb.com/title/tt109771
# 252  110189  http://www.imdb.com/title/tt110189
# 262  103994  http://www.imdb.com/title/tt103994
# 281  117169  http://www.imdb.com/title/tt117169
# 282  106402  http://www.imdb.com/title/tt106402
# 283  113948  http://www.imdb.com/title/tt113948
#
#                                                Title  IMDB Score  \
# 29             Yao a yao, yao dao wai po qiao (1995)         7.2
# 32                           Wings of Courage (1995)         6.5
# 36                     Across the Sea of Time (1995)         6.4
# 39                   Cry, the Beloved Country (1995)         6.9
# 45              How to Make an American Quilt (1995)         6.2
# 46                                      Se7en (1995)         8.6
# 50                             Guardian Angel (1994)         4.8
# 54                                    Georgia (1995)         6.5
# 55                    Kids of the Round Table (1995)         5.0
# 57                    Il Postino: The Postman (1994)         7.7
# 58                           Le confessionnal (1995)         7.6
# 71                      Kicking and Screaming (1995)         7.0
# 76                                  Nico Icon (1995)         7.3
# 81                             Antonia's Line (1995)         7.5
# 82   Once Upon a Time... When We Were Colored (1995)         7.2
# 83                Last Summer in the Hamptons (1995)         6.1
# 84                         Angels and Insects (1995)         7.0
# 89                 The Journey of August King (1995)         6.6
# 96                                   Shopping (1994)         5.4
# 97              Heidi Fleiss: Hollywood Madam (1995)         6.6
# 104                           Nobody Loves Me (1994)         7.3
# 106                                   Catwalk (1995)         6.4
# 107              Headless Body in Topless Bar (1995)         4.7
# 114                     Anne Frank Remembered (1995)         8.1
# 119                   The Boys of St. Vincent (1992)         7.7
# 125                The Silences of the Palace (1994)         7.4
# 126                            Jupiter's Wife (1995)         7.2
# 127                            Pie in the Sky (1996)         5.8
# 129                         Frankie Starlight (1995)         6.7
# 131                                 Nueba Yol (1995)         7.1
# 132                             Sonic Outlaws (1995)         7.3
# 134          From the Journals of Jean Seberg (1995)         7.1
# 136                            The Neon Bible (1995)         6.2
# 140                                    Cienie (1988)         6.3
# 141                                     Gospa (1995)         5.1
# 152                             Belle de Jour (1967)         7.8
# 154                          Blue in the Face (1995)         6.7
# 155                            Canadian Bacon (1995)         5.9
# 160                                     Crumb (1994)         8.0
# 176                      Love & Human Remains (1993)         6.7
# 182                                     Nadja (1994)         6.0
# 203                           Unstrung Heroes (1995)         6.7
# 204                                  Unzipped (1995)         6.4
# 223                                 Dream Man (1995)         4.6
# 239                                 Farinelli (1994)         6.9
# 252                            The Jerky Boys (1995)         4.6
# 262                  Como agua para chocolate (1992)         7.2
# 281                              New York Cop (1993)         4.2
# 282                             Beyond Bedlam (1994)         3.4
# 283                         Nemesis 2: Nebula (1995)         4.7
#
#                              Genre  \
# 29             Crime|Drama|Romance
# 32               Adventure|Romance
# 36          Adventure|Drama|Family
# 39                  Drama|Thriller
# 45            Comedy|Drama|Romance
# 46             Crime|Drama|Mystery
# 50           Action|Drama|Thriller
# 54                     Drama|Music
# 55         Adventure|Comedy|Family
# 57          Biography|Comedy|Drama
# 58          Drama|Mystery|Thriller
# 71            Comedy|Drama|Romance
# 76     Documentary|Biography|Music
# 81                    Comedy|Drama
# 82                   Drama|Romance
# 83                    Comedy|Drama
# 84                   Drama|Romance
# 89                           Drama
# 96              Action|Crime|Drama
# 97           Documentary|Biography
# 104                   Comedy|Drama
# 106                    Documentary
# 107             Comedy|Crime|Drama
# 114      Documentary|Biography|War
# 119                          Drama
# 125                          Drama
# 126  Documentary|Biography|Mystery
# 127                 Comedy|Romance
# 129              Drama|Romance|War
# 131                   Comedy|Drama
# 132                    Documentary
# 134          Documentary|Biography
# 136                          Drama
# 140                          Drama
# 141                          Drama
# 152                          Drama
# 154                         Comedy
# 155                         Comedy
# 160   Documentary|Biography|Comedy
# 176                   Drama|Comedy
# 182                   Drama|Horror
# 203                   Comedy|Drama
# 204                    Documentary
# 223                       Thriller
# 239          Biography|Drama|Music
# 252                   Comedy|Crime
# 262                  Drama|Romance
# 281             Action|Crime|Drama
# 282                  Comedy|Horror
# 283         Action|Sci-Fi|Thriller
#
#                                                 Poster  \
# 29   https://images-na.ssl-images-amazon.com/images...
# 32   https://images-na.ssl-images-amazon.com/images...
# 36   https://images-na.ssl-images-amazon.com/images...
# 39   https://images-na.ssl-images-amazon.com/images...
# 45   https://images-na.ssl-images-amazon.com/images...
# 46   https://images-na.ssl-images-amazon.com/images...
# 50   https://images-na.ssl-images-amazon.com/images...
# 54   https://images-na.ssl-images-amazon.com/images...
# 55   https://images-na.ssl-images-amazon.com/images...
# 57   https://images-na.ssl-images-amazon.com/images...
# 58   https://images-na.ssl-images-amazon.com/images...
# 71   https://images-na.ssl-images-amazon.com/images...
# 76   https://images-na.ssl-images-amazon.com/images...
# 81   https://images-na.ssl-images-amazon.com/images...
# 82   https://images-na.ssl-images-amazon.com/images...
# 83   https://images-na.ssl-images-amazon.com/images...
# 84   https://images-na.ssl-images-amazon.com/images...
# 89   https://images-na.ssl-images-amazon.com/images...
# 96   https://images-na.ssl-images-amazon.com/images...
# 97   https://images-na.ssl-images-amazon.com/images...
# 104  https://images-na.ssl-images-amazon.com/images...
# 106  https://images-na.ssl-images-amazon.com/images...
# 107  https://images-na.ssl-images-amazon.com/images...
# 114  https://images-na.ssl-images-amazon.com/images...
# 119  https://images-na.ssl-images-amazon.com/images...
# 125  https://images-na.ssl-images-amazon.com/images...
# 126  https://images-na.ssl-images-amazon.com/images...
# 127  https://images-na.ssl-images-amazon.com/images...
# 129  https://images-na.ssl-images-amazon.com/images...
# 131  https://images-na.ssl-images-amazon.com/images...
# 132  https://images-na.ssl-images-amazon.com/images...
# 134  https://images-na.ssl-images-amazon.com/images...
# 136  https://images-na.ssl-images-amazon.com/images...
# 140                                                NaN
# 141  https://images-na.ssl-images-amazon.com/images...
# 152  https://images-na.ssl-images-amazon.com/images...
# 154  https://images-na.ssl-images-amazon.com/images...
# 155  https://images-na.ssl-images-amazon.com/images...
# 160  https://images-na.ssl-images-amazon.com/images...
# 176  https://images-na.ssl-images-amazon.com/images...
# 182  https://images-na.ssl-images-amazon.com/images...
# 203  https://images-na.ssl-images-amazon.com/images...
# 204  https://images-na.ssl-images-amazon.com/images...
# 223  https://images-na.ssl-images-amazon.com/images...
# 239  https://images-na.ssl-images-amazon.com/images...
# 252  https://images-na.ssl-images-amazon.com/images...
# 262  https://images-na.ssl-images-amazon.com/images...
# 281  https://images-na.ssl-images-amazon.com/images...
# 282  https://images-na.ssl-images-amazon.com/images...
# 283  https://images-na.ssl-images-amazon.com/images...
#
#                         match_title
# 29           yaoayaoyaodaowaipoqiao
# 32                   wingsofcourage
# 36               acrosstheseaoftime
# 39             crythebelovedcountry
# 45         howtomakeanamericanquilt
# 46                            se7en
# 50                    guardianangel
# 54                          georgia
# 55              kidsoftheroundtable
# 57              ilpostinothepostman
# 58                  leconfessionnal
# 71              kickingandscreaming
# 76                         nicoicon
# 81                     antoniasline
# 82   onceuponatimewhenwewerecolored
# 83          lastsummerinthehamptons
# 84                 angelsandinsects
# 89           thejourneyofaugustking
# 96                         shopping
# 97        heidifleisshollywoodmadam
# 104                   nobodylovesme
# 106                         catwalk
# 107        headlessbodyintoplessbar
# 114             annefrankremembered
# 119              theboysofstvincent
# 125          thesilencesofthepalace
# 126                    jupiterswife
# 127                     pieinthesky
# 129                frankiestarlight
# 131                        nuebayol
# 132                    sonicoutlaws
# 134     fromthejournalsofjeanseberg
# 136                    theneonbible
# 140                          cienie
# 141                           gospa
# 152                     belledejour
# 154                   blueintheface
# 155                   canadianbacon
# 160                           crumb
# 176                lovehumanremains
# 182                           nadja
# 203                  unstrungheroes
# 204                        unzipped
# 223                        dreamman
# 239                       farinelli
# 252                    thejerkyboys
# 262           comoaguaparachocolate
# 281                      newyorkcop
# 282                    beyondbedlam
# 283                  nemesis2nebula

# %%
#makes sense, mispelling
movie_info[movie_info['title'] == "Seven"]
# Out:
#        wiki_ID freebase_ID  title        date  revenue  runtime  \
# 66693   206818   /m/01dc0c  Seven  1995-09-22      NaN    127.0
#
#                                  language  \
# 66693  {"/m/02h40lc": "English Language"}
#
#                                          country  \
# 66693  {"/m/09c7w0": "United States of America"}
#
#                                                   genres match_title
# 66693  {"/m/01jfsb": "Thriller", "/m/0lsxr": "Crime F...       seven

# %%
#not sure if this is 2 
movie_info[movie_info['title'] == "Poison Ivy"]
# Out:
#         wiki_ID freebase_ID       title        date  revenue  runtime  \
# 70247  17646903  /m/0462mpt  Poison Ivy  1985-02-10      NaN     97.0
# 78060    555857   /m/02plb3  Poison Ivy     1992-01      NaN     88.0
#
#                                  language  \
# 70247  {"/m/02h40lc": "English Language"}
# 78060  {"/m/02h40lc": "English Language"}
#
#                                          country  \
# 70247  {"/m/09c7w0": "United States of America"}
# 78060  {"/m/09c7w0": "United States of America"}
#
#                                                   genres match_title
# 70247  {"/m/06cvj": "Romantic comedy", "/m/01z4y": "C...   poisonivy
# 78060  {"/m/0hn10": "LGBT", "/m/01jfsb": "Thriller", ...   poisonivy

# %%
#fuzzy match?

# %% [markdown]
# ## Genre cleaning

# %%
movies_df.head()
# Out:
#     wiki_ID freebase_ID                      title        date      revenue  \
# 0    975900   /m/03vyhn             Ghosts of Mars  2001-08-24   14010832.0
# 1   9363483  /m/0285_cd           White Of The Eye        1987          NaN
# 2  18998739  /m/04jcqvw  The Sorcerer's Apprentice        2002          NaN
# 3  12621957  /m/05pdd86  The Sorcerer's Apprentice  2010-07-08  215283742.0
# 4   6631279   /m/0gffwj                Little city  1997-04-04          NaN
#
#    runtime                            language  \
# 0     98.0  {"/m/02h40lc": "English Language"}
# 1    110.0  {"/m/02h40lc": "English Language"}
# 2     86.0  {"/m/02h40lc": "English Language"}
# 3    111.0  {"/m/02h40lc": "English Language"}
# 4     93.0  {"/m/02h40lc": "English Language"}
#
#                                      country  \
# 0  {"/m/09c7w0": "United States of America"}
# 1             {"/m/07ssc": "United Kingdom"}
# 2               {"/m/0hzlz": "South Africa"}
# 3  {"/m/09c7w0": "United States of America"}
# 4  {"/m/09c7w0": "United States of America"}
#
#                                               genres             match_title  \
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...            ghostsofmars
# 1  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...           whiteoftheeye
# 2  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...  thesorcerersapprentice
# 3  {"/m/06n90": "Science Fiction", "/m/03k9fj": "...  thesorcerersapprentice
# 4  {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...              littlecity
#
#                                                 plot  imdbId  \
# 0  Set in the second half of the 22nd century, th...  228333
# 1  A series of murders of rich young women throug...   94320
# 2  Every hundred years, the evil Morgana  returns...  963966
# 3   In AD 740, one of Merlin's  three apprentices...  963966
# 4  Adam, a San Francisco-based artist who works a...  119548
#
#                             Imdb Link                             Title  \
# 0  http://www.imdb.com/title/tt228333             Ghosts of Mars (2001)
# 1   http://www.imdb.com/title/tt94320           White of the Eye (1987)
# 2  http://www.imdb.com/title/tt963966  The Sorcerer's Apprentice (2010)
# 3  http://www.imdb.com/title/tt963966  The Sorcerer's Apprentice (2010)
# 4  http://www.imdb.com/title/tt119548                Little City (1997)
#
#    IMDB Score                    Genre  \
# 0         4.9     Action|Horror|Sci-Fi
# 1         6.4          Horror|Thriller
# 2         6.1  Action|Adventure|Family
# 3         6.1  Action|Adventure|Family
# 4         6.1           Comedy|Romance
#
#                                               Poster
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
# 3  https://images-na.ssl-images-amazon.com/images...
# 4  https://images-na.ssl-images-amazon.com/images...

# %%
#oh no genres is not a dictionary, it's a string 
#this is slightly more annoying to handle 
#list_genres = lambda x: list(x.values)
#movies_df['genres_list'] = movies_df["genres"].apply(list_genres)
#movies_df.head()

# %%
def remove_ids(genre_str): 
    #split string on colons and commas
    genre_id_lists = re.split(': |, ', genre_str)
    #select odd values (genres)
    genre_list = genre_id_lists[1::2]
    #remove unnecessary quotes
    clean_genres = [re.sub('[""{}]', '', g) for g in genre_list] 
    return clean_genres


movies_df['clean_genres'] = movies_df.apply(lambda x: remove_ids(x.genres), axis=1)

# %%
movies_df.head(10)
# Out:
#     wiki_ID freebase_ID                      title        date      revenue  \
# 0    975900   /m/03vyhn             Ghosts of Mars  2001-08-24   14010832.0
# 1   9363483  /m/0285_cd           White Of The Eye        1987          NaN
# 2  18998739  /m/04jcqvw  The Sorcerer's Apprentice        2002          NaN
# 3  12621957  /m/05pdd86  The Sorcerer's Apprentice  2010-07-08  215283742.0
# 4   6631279   /m/0gffwj                Little city  1997-04-04          NaN
# 5    171005   /m/016ywb                    Henry V  1989-11-08   10161099.0
# 6    171005   /m/016ywb                    Henry V  1989-11-08   10161099.0
# 7     80493    /m/0ktqc                    Henry V        1944          NaN
# 8     80493    /m/0ktqc                    Henry V        1944          NaN
# 9     77856    /m/0kcn7               Mary Poppins  1964-08-27  102272727.0
#
#    runtime                            language  \
# 0     98.0  {"/m/02h40lc": "English Language"}
# 1    110.0  {"/m/02h40lc": "English Language"}
# 2     86.0  {"/m/02h40lc": "English Language"}
# 3    111.0  {"/m/02h40lc": "English Language"}
# 4     93.0  {"/m/02h40lc": "English Language"}
# 5    137.0  {"/m/02h40lc": "English Language"}
# 6    137.0  {"/m/02h40lc": "English Language"}
# 7    135.0  {"/m/02h40lc": "English Language"}
# 8    135.0  {"/m/02h40lc": "English Language"}
# 9    139.0  {"/m/02h40lc": "English Language"}
#
#                                              country  \
# 0          {"/m/09c7w0": "United States of America"}
# 1                     {"/m/07ssc": "United Kingdom"}
# 2                       {"/m/0hzlz": "South Africa"}
# 3          {"/m/09c7w0": "United States of America"}
# 4          {"/m/09c7w0": "United States of America"}
# 5                     {"/m/07ssc": "United Kingdom"}
# 6                     {"/m/07ssc": "United Kingdom"}
# 7  {"/m/09c7w0": "United States of America", "/m/...
# 8  {"/m/09c7w0": "United States of America", "/m/...
# 9          {"/m/09c7w0": "United States of America"}
#
#                                               genres             match_title  \
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...            ghostsofmars
# 1  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...           whiteoftheeye
# 2  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...  thesorcerersapprentice
# 3  {"/m/06n90": "Science Fiction", "/m/03k9fj": "...  thesorcerersapprentice
# 4  {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...              littlecity
# 5  {"/m/04xvh5": "Costume drama", "/m/082gq": "Wa...                  henryv
# 6  {"/m/04xvh5": "Costume drama", "/m/082gq": "Wa...                  henryv
# 7  {"/m/04xvh5": "Costume drama", "/m/0520lz": "R...                  henryv
# 8  {"/m/04xvh5": "Costume drama", "/m/0520lz": "R...                  henryv
# 9  {"/m/0hj3myq": "Children's/Family", "/m/04t36"...             marypoppins
#
#                                                 plot  imdbId  \
# 0  Set in the second half of the 22nd century, th...  228333
# 1  A series of murders of rich young women throug...   94320
# 2  Every hundred years, the evil Morgana  returns...  963966
# 3   In AD 740, one of Merlin's  three apprentices...  963966
# 4  Adam, a San Francisco-based artist who works a...  119548
# 5  {{Plot|dateAct 1Act 2Act 3Act 4Act 5 Finally n...   97499
# 6  {{Plot|dateAct 1Act 2Act 3Act 4Act 5 Finally n...   36910
# 7   We first see a panorama of London in 1600. We...   97499
# 8   We first see a panorama of London in 1600. We...   36910
# 9  The film opens with Mary Poppins  perched in a...   58331
#
#                             Imdb Link                             Title  \
# 0  http://www.imdb.com/title/tt228333             Ghosts of Mars (2001)
# 1   http://www.imdb.com/title/tt94320           White of the Eye (1987)
# 2  http://www.imdb.com/title/tt963966  The Sorcerer's Apprentice (2010)
# 3  http://www.imdb.com/title/tt963966  The Sorcerer's Apprentice (2010)
# 4  http://www.imdb.com/title/tt119548                Little City (1997)
# 5   http://www.imdb.com/title/tt97499                    Henry V (1989)
# 6   http://www.imdb.com/title/tt36910                    Henry V (1944)
# 7   http://www.imdb.com/title/tt97499                    Henry V (1989)
# 8   http://www.imdb.com/title/tt36910                    Henry V (1944)
# 9   http://www.imdb.com/title/tt58331               Mary Poppins (1964)
#
#    IMDB Score                    Genre  \
# 0         4.9     Action|Horror|Sci-Fi
# 1         6.4          Horror|Thriller
# 2         6.1  Action|Adventure|Family
# 3         6.1  Action|Adventure|Family
# 4         6.1           Comedy|Romance
# 5         7.7   Action|Biography|Drama
# 6         7.3  Biography|Drama|History
# 7         7.7   Action|Biography|Drama
# 8         7.3  Biography|Drama|History
# 9         7.8    Comedy|Family|Fantasy
#
#                                               Poster  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
# 3  https://images-na.ssl-images-amazon.com/images...
# 4  https://images-na.ssl-images-amazon.com/images...
# 5  https://images-na.ssl-images-amazon.com/images...
# 6  https://images-na.ssl-images-amazon.com/images...
# 7  https://images-na.ssl-images-amazon.com/images...
# 8  https://images-na.ssl-images-amazon.com/images...
# 9  https://images-na.ssl-images-amazon.com/images...
#
#                                          noid_genres  \
# 0  ["Thriller", "Science Fiction", "Horror", "Adv...
# 1  ["Thriller", "Erotic thriller", "Psychological...
# 2  ["Family Film", "Fantasy", "Adventure", "World...
# 3  ["Science Fiction", "Adventure", "Fantasy", "C...
# 4  ["Romantic comedy", "Ensemble Film", "Comedy-d...
# 5  ["Costume drama", "War film", "Epic", "Period ...
# 6  ["Costume drama", "War film", "Epic", "Period ...
# 7  ["Costume drama", "Roadshow theatrical release...
# 8  ["Costume drama", "Roadshow theatrical release...
# 9  ["Children's/Family", "Musical", "Fantasy", "C...
#
#                                         clean_genres
# 0  [Thriller, Science Fiction, Horror, Adventure,...
# 1  [Thriller, Erotic thriller, Psychological thri...
# 2    [Family Film, Fantasy, Adventure, World cinema]
# 3  [Science Fiction, Adventure, Fantasy, Comedy, ...
# 4  [Romantic comedy, Ensemble Film, Comedy-drama,...
# 5  [Costume drama, War film, Epic, Period piece, ...
# 6  [Costume drama, War film, Epic, Period piece, ...
# 7  [Costume drama, Roadshow theatrical release, D...
# 8  [Costume drama, Roadshow theatrical release, D...
# 9  [Children's/Family, Musical, Fantasy, Comedy, ...

# %%
movies_df.iloc[0,-1]
# Out:
# ['Thriller',
#  'Science Fiction',
#  'Horror',
#  'Adventure',
#  'Supernatural',
#  'Action',
#  'Space western']

# %%
#there are many genres that can be applied to film 
#in this case, let's just keep it simple and select the first one
#they're not ordered alphabetically

# %% [markdown]
# ## Bechdel Test

# %%
bechdel_df = pd.read_csv('bechdel_movies.csv')
bechdel_df.head()
# Out:
#    Unnamed: 0  year       imdb             title             test clean_test  \
# 0           1  2013  tt1711425     21 &amp; Over           notalk     notalk
# 1           2  2012  tt1343727          Dredd 3D      ok-disagree         ok
# 2           3  2013  tt2024544  12 Years a Slave  notalk-disagree     notalk
# 3           4  2013  tt1272878            2 Guns           notalk     notalk
# 4           5  2013  tt0453562                42              men        men
#
#   binary      budget    domgross     intgross  ...           director  \
# 0   FAIL  13000000.0  25682380.0   42195766.0  ...                NaN
# 1   PASS  45000000.0  13414714.0   40868994.0  ...                NaN
# 2   FAIL  20000000.0  53107035.0  158607035.0  ...      Steve McQueen
# 3   FAIL  61000000.0  75612460.0  132493015.0  ...  Baltasar Kormákur
# 4   FAIL  40000000.0  95020213.0   95020213.0  ...    Brian Helgeland
#
#       released                                             actors  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2  08 Nov 2013  Chiwetel Ejiofor, Dwight Henry, Dickie Gravois...
# 3  02 Aug 2013  Denzel Washington, Mark Wahlberg, Paula Patton...
# 4  12 Apr 2013  Chadwick Boseman, Harrison Ford, Nicole Behari...
#
#                        genre  \
# 0                        NaN
# 1                        NaN
# 2  Biography, Drama, History
# 3      Action, Comedy, Crime
# 4    Biography, Drama, Sport
#
#                                               awards  runtime   type  \
# 0                                                NaN      NaN    NaN
# 1                                                NaN      NaN    NaN
# 2  Won 3 Oscars. Another 131 wins & 137 nominations.  134 min  movie
# 3                                             1 win.  109 min  movie
# 4                           3 wins & 13 nominations.  128 min  movie
#
#                                               poster imdb_votes error
# 0                                                NaN        NaN   NaN
# 1                                                NaN        NaN   NaN
# 2  http://ia.media-imdb.com/images/M/MV5BMjExMTEz...   143446.0   NaN
# 3  http://ia.media-imdb.com/images/M/MV5BNTQ5MTgz...    87301.0   NaN
# 4  http://ia.media-imdb.com/images/M/MV5BMTQwMDU4...    43608.0   NaN
#
# [5 rows x 35 columns]

# %%
bechdel_df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'imdb', 'title', 'test', 'clean_test', 'binary',
#        'budget', 'domgross', 'intgross', 'code', 'budget_2013',
#        'domgross_2013', 'intgross_2013', 'period_code', 'decade_code',
#        'imdb_id', 'plot', 'rated', 'response', 'language', 'country', 'writer',
#        'metascore', 'imdb_rating', 'director', 'released', 'actors', 'genre',
#        'awards', 'runtime', 'type', 'poster', 'imdb_votes', 'error'],
#       dtype='object')

# %%
#use imdb id to merge in to dataset with plots 

movies_bechdel = movies_df_plots.merge(bechdel_df, how = 'inner', left_on = 'imdbId', right_on ='imdb_id')
movies_bechdel.head()
# Out:
#     wiki_ID freebase_ID                    title_x        date      revenue  \
# 0  18998739  /m/04jcqvw  The Sorcerer's Apprentice        2002          NaN
# 1  12621957  /m/05pdd86  The Sorcerer's Apprentice  2010-07-08  215283742.0
# 2    171005   /m/016ywb                    Henry V  1989-11-08   10161099.0
# 3     80493    /m/0ktqc                    Henry V        1944          NaN
# 4  28271896  /m/0cp0zcq                    The Net  1953-11-05          NaN
#
#    runtime_x                          language_x  \
# 0       86.0  {"/m/02h40lc": "English Language"}
# 1      111.0  {"/m/02h40lc": "English Language"}
# 2      137.0  {"/m/02h40lc": "English Language"}
# 3      135.0  {"/m/02h40lc": "English Language"}
# 4       86.0  {"/m/02h40lc": "English Language"}
#
#                                            country_x  \
# 0                       {"/m/0hzlz": "South Africa"}
# 1          {"/m/09c7w0": "United States of America"}
# 2                     {"/m/07ssc": "United Kingdom"}
# 3  {"/m/09c7w0": "United States of America", "/m/...
# 4                     {"/m/07ssc": "United Kingdom"}
#
#                                               genres             match_title  \
# 0  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...  thesorcerersapprentice
# 1  {"/m/06n90": "Science Fiction", "/m/03k9fj": "...  thesorcerersapprentice
# 2  {"/m/04xvh5": "Costume drama", "/m/082gq": "Wa...                  henryv
# 3  {"/m/04xvh5": "Costume drama", "/m/0520lz": "R...                  henryv
# 4                            {"/m/07s9rl0": "Drama"}                  thenet
#
#    ...         director     released  \
# 0  ...              NaN          NaN
# 1  ...              NaN          NaN
# 2  ...  Kenneth Branagh  08 Nov 1989
# 3  ...  Kenneth Branagh  08 Nov 1989
# 4  ...    Irwin Winkler  28 Jul 1995
#
#                                               actors  \
# 0                                                NaN
# 1                                                NaN
# 2  Derek Jacobi, Kenneth Branagh, Simon Shepherd,...
# 3  Derek Jacobi, Kenneth Branagh, Simon Shepherd,...
# 4  Sandra Bullock, Jeremy Northam, Dennis Miller,...
#
#                       genre                                          awards  \
# 0                       NaN                                             NaN
# 1                       NaN                                             NaN
# 2  Action, Biography, Drama  Won 1 Oscar. Another 10 wins & 11 nominations.
# 3  Action, Biography, Drama  Won 1 Oscar. Another 10 wins & 11 nominations.
# 4      Action, Crime, Drama                                   1 nomination.
#
#   runtime_y   type                                             poster  \
# 0       NaN    NaN                                                NaN
# 1       NaN    NaN                                                NaN
# 2   137 min  movie  http://ia.media-imdb.com/images/M/MV5BMTI1ODg1...
# 3   137 min  movie  http://ia.media-imdb.com/images/M/MV5BMTI1ODg1...
# 4   114 min  movie  http://ia.media-imdb.com/images/M/MV5BMTU0NjA2...
#
#    imdb_votes error
# 0         NaN   NaN
# 1         NaN   NaN
# 2     20002.0   NaN
# 3     20002.0   NaN
# 4     40448.0   NaN
#
# [5 rows x 52 columns]

# %%
len(movies_bechdel)
#veryyy small!
# Out:
# 2037

# %%
#save anyway? 
movies_bechdel.to_csv('small_matched_bechdel.csv')
